# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np 
print("Packages successfully imported")
# Out:
# Packages successfully imported

# %%
input  = cv2.imread('/home/tk_conda/Documents/Shoriya/OpenCV/nature.jpg')

# %%
plt.imshow(cv2.cvtColor(input, cv2.COLOR_BGR2RGB))
plt.title('Nature')

plt.show()

# %%
print (input.shape)
# Out:
# (188, 250, 3)

# %%
print ('Height of Image:', int(input.shape[0]), 'pixels')
print ('Width of Image: ', int(input.shape[1]), 'pixels')
# Out:
# Height of Image: 188 pixels
# Width of Image:  250 pixels

# %%
df=cv2.imwrite('output.jpg', input)
cv2.imwrite('output.png', input)
# Out:
# True

# %%
gray_image = cv2.cvtColor(input, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB))
plt.title('GreyImage-Nature')

plt.show()

# %%
row, col = 1, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()

axs[0].imshow(cv2.cvtColor(input, cv2.COLOR_BGR2RGB))
axs[0].set_title('Original')

axs[1].imshow(cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB))
axs[1].set_title('Grayscale')

plt.show()

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('Grayscale.jpg', gray_image)
cv2.imwrite('Grayscale.png', gray_image)
# Out:
# True

# %%
input_gray  = cv2.imread('/home/tk_conda/Documents/Shoriya/OpenCV/Grayscale.jpg') 
hsv_image = cv2.cvtColor(input_gray, cv2.COLOR_BGR2HSV)


row, col = 2, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()
 
axs[0][0].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('HSV image')

axs[0][1].imshow(cv2.cvtColor(hsv_image[:, :, 0], cv2.COLOR_BGR2RGB))
axs[0][1].set_title('Hue channel')

axs[1][0].imshow(cv2.cvtColor(hsv_image[:, :, 1], cv2.COLOR_BGR2RGB))
axs[1][0].set_title('Saturation channel')

axs[1][1].imshow(cv2.cvtColor(hsv_image[:, :, 2], cv2.COLOR_BGR2RGB))
axs[1][1].set_title('Value channel')

plt.show()

# %%
 
hsv_image = cv2.cvtColor(input, cv2.COLOR_BGR2HSV)


row, col = 2, 2
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()
 
axs[0][0].imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('HSV image')

axs[0][1].imshow(cv2.cvtColor(hsv_image[:, :, 0], cv2.COLOR_BGR2RGB))
axs[0][1].set_title('Hue channel')

axs[1][0].imshow(cv2.cvtColor(hsv_image[:, :, 1], cv2.COLOR_BGR2RGB))
axs[1][0].set_title('Saturation channel')

axs[1][1].imshow(cv2.cvtColor(hsv_image[:, :, 2], cv2.COLOR_BGR2RGB))
axs[1][1].set_title('Value channel')

plt.show()

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('hsv_image.jpg', hsv_image)
cv2.imwrite('hsv_image.png', hsv_image)
cv2.imwrite('hue_channel.jpg', hsv_image[:, :, 0])
cv2.imwrite('hue_channel.png', hsv_image[:, :, 0])
cv2.imwrite('saturation_channel.jpg', hsv_image[:, :, 1])
cv2.imwrite('saturation_channel.png', hsv_image[:, :, 1])
cv2.imwrite('value_channel.jpg', hsv_image[:, :, 2])
cv2.imwrite('value_channel.png', hsv_image[:, :, 2])
# Out:
# True
